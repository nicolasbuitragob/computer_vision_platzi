# %%
import os
import json
import pickle
import shutil
import pandas as pd

import tensorflow as tf

from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2

from google.protobuf import text_format

# %%
# Set up labels and pre trained model

# %%
labels = [{'name':'car',
           'id':1
          },
          {'name':'motorbike',
           'id':2
          }]

# %%
with open('label_map.pbxt','w') as f:
    for label in labels:
        f.write('item { \n')
        f.write(f"\tname:\'{label['name']}\'\n")
        f.write(f"\tid:{label['id']}\n")
        f.write('}\n')

# %%
# Mobilenet model dowloaded from terminal using:  

# wget --no-check-certificate http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz -O ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz

# see docs : https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md
mobilenet_dir = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/'

# %%
# config file cominig from pretrained architecture
# config pipeline file has all the configuration parameters that the model will use while learning
# params like batch size, image reshape, data augmentation config, regularization etc

# %%
path_training = 'ssd_mobilenet'

# %%
source_config = f"{mobilenet_dir}/pipeline.config"
target_config = f"{path_training}/pipeline.config"
shutil.copyfile(source_config, target_config)
# Out:
# 'ssd_mobilenet/pipeline.config'

# %%
# Set up config file to make it editable

# %%
config = config_util.get_configs_from_pipeline_file(target_config)

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(target_config,"r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
label_map_pbxt_fname = 'label_map.pbxt'
train_record_path = 'train.record'
test_record_path = 'test.record'

# %%
# EDIT THE PIPELINE.CONFIG FILE
pipeline_config.model.ssd.num_classes = 2
pipeline_config.train_config.batch_size = 8
pipeline_config.train_config.fine_tune_checkpoint = f"{mobilenet_dir}/checkpoint/ckpt-0"
pipeline_config.train_config.fine_tune_checkpoint_type = 'detection'

pipeline_config.train_input_reader.label_map_path = label_map_pbxt_fname
pipeline_config.train_input_reader.tf_record_input_reader.input_path[0] = train_record_path

pipeline_config.eval_input_reader[0].label_map_path = label_map_pbxt_fname
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[0] = test_record_path

# %%
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(target_config, "wb") as f:
    f.write(config_text)

# %%
# %load_exting config
num_steps = 100
model_dir = path_training

# !python3 models/research/object_detection/model_main_tf2.py\
--pipeline_config_path={target_config} \
--model_dir={model_dir} \
--num_training_steps={num_steps}
# Out:
# 2022-09-17 20:02:54.335836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.342650: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.343062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.343726: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-17 20:02:54.344729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.345115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.345540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.774542: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.774835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.775078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:02:54.775297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3117 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0917 20:02:54.779233 139634860230464 mirrored_strategy.py:376] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0917 20:02:54.781818 139634860230464 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0917 20:02:54.781883 139634860230464 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0917 20:02:54.909800 139634860230464 deprecation.py:341] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['train.record']
# I0917 20:02:54.911995 139634860230464 dataset_builder.py:162] Reading unweighted datasets: ['train.record']
# INFO:tensorflow:Reading record datasets for input file: ['train.record']
# I0917 20:02:54.912090 139634860230464 dataset_builder.py:79] Reading record datasets for input file: ['train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0917 20:02:54.912137 139634860230464 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0917 20:02:54.912175 139634860230464 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0917 20:02:54.913806 139634860230464 deprecation.py:341] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0917 20:02:54.939152 139634860230464 deprecation.py:341] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0917 20:02:59.464577 139634860230464 deprecation.py:341] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0917 20:03:01.485202 139634860230464 deprecation.py:341] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0917 20:03:02.570236 139634860230464 deprecation.py:341] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2022-09-17 20:03:04.460433: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at multi_device_iterator_ops.cc:789 : NOT_FOUND: Resource AnonymousMultiDeviceIterator/AnonymousMultiDeviceIterator0/N10tensorflow4data12_GLOBAL__N_119MultiDeviceIteratorE does not exist.
# /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/keras/backend.py:414: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2022-09-17 20:03:20.327663: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8500
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.883441 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.884297 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.885681 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.886293 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.887647 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.888242 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.889601 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.890200 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.891612 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0917 20:03:22.892297 139634860230464 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0917 20:03:23.291216 139628682131200 deprecation.py:545] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.589s
# I0917 20:04:21.927172 139634860230464 model_lib_v2.py:705] Step 100 per-step time 0.589s
# INFO:tensorflow:{'Loss/classification_loss': 0.3528349,
#  'Loss/localization_loss': 0.39106178,
#  'Loss/regularization_loss': 0.15417716,
#  'Loss/total_loss': 0.8980739,
#  'learning_rate': 0.0319994}
# I0917 20:04:21.927648 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.3528349,
#  'Loss/localization_loss': 0.39106178,
#  'Loss/regularization_loss': 0.15417716,
#  'Loss/total_loss': 0.8980739,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.320s
# I0917 20:04:53.937925 139634860230464 model_lib_v2.py:705] Step 200 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.1477048,
#  'Loss/localization_loss': 0.20706606,
#  'Loss/regularization_loss': 0.15424828,
#  'Loss/total_loss': 0.50901914,
#  'learning_rate': 0.0373328}
# I0917 20:04:53.938256 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.1477048,
#  'Loss/localization_loss': 0.20706606,
#  'Loss/regularization_loss': 0.15424828,
#  'Loss/total_loss': 0.50901914,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.321s
# I0917 20:05:26.039673 139634860230464 model_lib_v2.py:705] Step 300 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.12722975,
#  'Loss/localization_loss': 0.13872968,
#  'Loss/regularization_loss': 0.15415797,
#  'Loss/total_loss': 0.4201174,
#  'learning_rate': 0.0426662}
# I0917 20:05:26.040102 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.12722975,
#  'Loss/localization_loss': 0.13872968,
#  'Loss/regularization_loss': 0.15415797,
#  'Loss/total_loss': 0.4201174,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.320s
# I0917 20:05:58.030760 139634860230464 model_lib_v2.py:705] Step 400 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.17669037,
#  'Loss/localization_loss': 0.08278464,
#  'Loss/regularization_loss': 0.15391186,
#  'Loss/total_loss': 0.41338685,
#  'learning_rate': 0.047999598}
# I0917 20:05:58.031251 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.17669037,
#  'Loss/localization_loss': 0.08278464,
#  'Loss/regularization_loss': 0.15391186,
#  'Loss/total_loss': 0.41338685,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.319s
# I0917 20:06:29.914502 139634860230464 model_lib_v2.py:705] Step 500 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.18433276,
#  'Loss/localization_loss': 0.060358953,
#  'Loss/regularization_loss': 0.15361121,
#  'Loss/total_loss': 0.3983029,
#  'learning_rate': 0.053333}
# I0917 20:06:29.915136 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.18433276,
#  'Loss/localization_loss': 0.060358953,
#  'Loss/regularization_loss': 0.15361121,
#  'Loss/total_loss': 0.3983029,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.320s
# I0917 20:07:01.914075 139634860230464 model_lib_v2.py:705] Step 600 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.12996642,
#  'Loss/localization_loss': 0.07177095,
#  'Loss/regularization_loss': 0.15328918,
#  'Loss/total_loss': 0.35502654,
#  'learning_rate': 0.0586664}
# I0917 20:07:01.914646 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.12996642,
#  'Loss/localization_loss': 0.07177095,
#  'Loss/regularization_loss': 0.15328918,
#  'Loss/total_loss': 0.35502654,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.319s
# I0917 20:07:33.793534 139634860230464 model_lib_v2.py:705] Step 700 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.10192719,
#  'Loss/localization_loss': 0.03878249,
#  'Loss/regularization_loss': 0.15286385,
#  'Loss/total_loss': 0.29357353,
#  'learning_rate': 0.0639998}
# I0917 20:07:33.794286 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.10192719,
#  'Loss/localization_loss': 0.03878249,
#  'Loss/regularization_loss': 0.15286385,
#  'Loss/total_loss': 0.29357353,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.319s
# I0917 20:08:05.709944 139634860230464 model_lib_v2.py:705] Step 800 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.080293424,
#  'Loss/localization_loss': 0.08385189,
#  'Loss/regularization_loss': 0.1523763,
#  'Loss/total_loss': 0.3165216,
#  'learning_rate': 0.069333196}
# I0917 20:08:05.710261 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.080293424,
#  'Loss/localization_loss': 0.08385189,
#  'Loss/regularization_loss': 0.1523763,
#  'Loss/total_loss': 0.3165216,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.320s
# I0917 20:08:37.688375 139634860230464 model_lib_v2.py:705] Step 900 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.0770448,
#  'Loss/localization_loss': 0.03482377,
#  'Loss/regularization_loss': 0.1517874,
#  'Loss/total_loss': 0.26365596,
#  'learning_rate': 0.074666604}
# I0917 20:08:37.688662 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.0770448,
#  'Loss/localization_loss': 0.03482377,
#  'Loss/regularization_loss': 0.1517874,
#  'Loss/total_loss': 0.26365596,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.317s
# I0917 20:09:09.456047 139634860230464 model_lib_v2.py:705] Step 1000 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.07862739,
#  'Loss/localization_loss': 0.02670337,
#  'Loss/regularization_loss': 0.15113612,
#  'Loss/total_loss': 0.25646687,
#  'learning_rate': 0.08}
# I0917 20:09:09.456621 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.07862739,
#  'Loss/localization_loss': 0.02670337,
#  'Loss/regularization_loss': 0.15113612,
#  'Loss/total_loss': 0.25646687,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.321s
# I0917 20:09:41.568143 139634860230464 model_lib_v2.py:705] Step 1100 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.08612265,
#  'Loss/localization_loss': 0.03332003,
#  'Loss/regularization_loss': 0.150579,
#  'Loss/total_loss': 0.27002168,
#  'learning_rate': 0.07999918}
# I0917 20:09:41.568495 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.08612265,
#  'Loss/localization_loss': 0.03332003,
#  'Loss/regularization_loss': 0.150579,
#  'Loss/total_loss': 0.27002168,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.318s
# I0917 20:10:13.357970 139634860230464 model_lib_v2.py:705] Step 1200 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.085971385,
#  'Loss/localization_loss': 0.03923014,
#  'Loss/regularization_loss': 0.14996137,
#  'Loss/total_loss': 0.27516288,
#  'learning_rate': 0.079996705}
# I0917 20:10:13.358540 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.085971385,
#  'Loss/localization_loss': 0.03923014,
#  'Loss/regularization_loss': 0.14996137,
#  'Loss/total_loss': 0.27516288,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.320s
# I0917 20:10:45.371227 139634860230464 model_lib_v2.py:705] Step 1300 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.06630895,
#  'Loss/localization_loss': 0.035260286,
#  'Loss/regularization_loss': 0.14924546,
#  'Loss/total_loss': 0.25081468,
#  'learning_rate': 0.0799926}
# I0917 20:10:45.371388 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.06630895,
#  'Loss/localization_loss': 0.035260286,
#  'Loss/regularization_loss': 0.14924546,
#  'Loss/total_loss': 0.25081468,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.321s
# I0917 20:11:17.459283 139634860230464 model_lib_v2.py:705] Step 1400 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.07032917,
#  'Loss/localization_loss': 0.02356822,
#  'Loss/regularization_loss': 0.14847541,
#  'Loss/total_loss': 0.2423728,
#  'learning_rate': 0.07998685}
# I0917 20:11:17.459773 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.07032917,
#  'Loss/localization_loss': 0.02356822,
#  'Loss/regularization_loss': 0.14847541,
#  'Loss/total_loss': 0.2423728,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.320s
# I0917 20:11:49.442341 139634860230464 model_lib_v2.py:705] Step 1500 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.07118684,
#  'Loss/localization_loss': 0.03039638,
#  'Loss/regularization_loss': 0.1477676,
#  'Loss/total_loss': 0.24935082,
#  'learning_rate': 0.07997945}
# I0917 20:11:49.442760 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.07118684,
#  'Loss/localization_loss': 0.03039638,
#  'Loss/regularization_loss': 0.1477676,
#  'Loss/total_loss': 0.24935082,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.322s
# I0917 20:12:21.608143 139634860230464 model_lib_v2.py:705] Step 1600 per-step time 0.322s
# INFO:tensorflow:{'Loss/classification_loss': 0.038832776,
#  'Loss/localization_loss': 0.017176274,
#  'Loss/regularization_loss': 0.14702,
#  'Loss/total_loss': 0.20302905,
#  'learning_rate': 0.079970405}
# I0917 20:12:21.608738 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.038832776,
#  'Loss/localization_loss': 0.017176274,
#  'Loss/regularization_loss': 0.14702,
#  'Loss/total_loss': 0.20302905,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.323s
# I0917 20:12:53.866475 139634860230464 model_lib_v2.py:705] Step 1700 per-step time 0.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.042490985,
#  'Loss/localization_loss': 0.01156544,
#  'Loss/regularization_loss': 0.14626221,
#  'Loss/total_loss': 0.20031863,
#  'learning_rate': 0.07995972}
# I0917 20:12:53.866755 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.042490985,
#  'Loss/localization_loss': 0.01156544,
#  'Loss/regularization_loss': 0.14626221,
#  'Loss/total_loss': 0.20031863,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.323s
# I0917 20:13:26.205117 139634860230464 model_lib_v2.py:705] Step 1800 per-step time 0.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.06933554,
#  'Loss/localization_loss': 0.023280373,
#  'Loss/regularization_loss': 0.14566998,
#  'Loss/total_loss': 0.2382859,
#  'learning_rate': 0.0799474}
# I0917 20:13:26.205917 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.06933554,
#  'Loss/localization_loss': 0.023280373,
#  'Loss/regularization_loss': 0.14566998,
#  'Loss/total_loss': 0.2382859,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.320s
# I0917 20:13:58.189992 139634860230464 model_lib_v2.py:705] Step 1900 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.06168545,
#  'Loss/localization_loss': 0.022627858,
#  'Loss/regularization_loss': 0.14491367,
#  'Loss/total_loss': 0.22922698,
#  'learning_rate': 0.07993342}
# I0917 20:13:58.190413 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.06168545,
#  'Loss/localization_loss': 0.022627858,
#  'Loss/regularization_loss': 0.14491367,
#  'Loss/total_loss': 0.22922698,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.321s
# I0917 20:14:30.263418 139634860230464 model_lib_v2.py:705] Step 2000 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.076931454,
#  'Loss/localization_loss': 0.044291954,
#  'Loss/regularization_loss': 0.14416268,
#  'Loss/total_loss': 0.2653861,
#  'learning_rate': 0.07991781}
# I0917 20:14:30.263633 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.076931454,
#  'Loss/localization_loss': 0.044291954,
#  'Loss/regularization_loss': 0.14416268,
#  'Loss/total_loss': 0.2653861,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.321s
# I0917 20:15:02.405411 139634860230464 model_lib_v2.py:705] Step 2100 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.067425035,
#  'Loss/localization_loss': 0.017143333,
#  'Loss/regularization_loss': 0.14343019,
#  'Loss/total_loss': 0.22799855,
#  'learning_rate': 0.07990056}
# I0917 20:15:02.405627 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.067425035,
#  'Loss/localization_loss': 0.017143333,
#  'Loss/regularization_loss': 0.14343019,
#  'Loss/total_loss': 0.22799855,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.321s
# I0917 20:15:34.550355 139634860230464 model_lib_v2.py:705] Step 2200 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.05959017,
#  'Loss/localization_loss': 0.009388005,
#  'Loss/regularization_loss': 0.14266747,
#  'Loss/total_loss': 0.21164565,
#  'learning_rate': 0.07988167}
# I0917 20:15:34.550690 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.05959017,
#  'Loss/localization_loss': 0.009388005,
#  'Loss/regularization_loss': 0.14266747,
#  'Loss/total_loss': 0.21164565,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.320s
# I0917 20:16:06.548188 139634860230464 model_lib_v2.py:705] Step 2300 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.045621417,
#  'Loss/localization_loss': 0.019515926,
#  'Loss/regularization_loss': 0.14193127,
#  'Loss/total_loss': 0.2070686,
#  'learning_rate': 0.07986114}
# I0917 20:16:06.548622 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.045621417,
#  'Loss/localization_loss': 0.019515926,
#  'Loss/regularization_loss': 0.14193127,
#  'Loss/total_loss': 0.2070686,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.320s
# I0917 20:16:38.576490 139634860230464 model_lib_v2.py:705] Step 2400 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.076351866,
#  'Loss/localization_loss': 0.030488655,
#  'Loss/regularization_loss': 0.14117146,
#  'Loss/total_loss': 0.24801198,
#  'learning_rate': 0.07983897}
# I0917 20:16:38.577305 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.076351866,
#  'Loss/localization_loss': 0.030488655,
#  'Loss/regularization_loss': 0.14117146,
#  'Loss/total_loss': 0.24801198,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.320s
# I0917 20:17:10.542815 139634860230464 model_lib_v2.py:705] Step 2500 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.060925838,
#  'Loss/localization_loss': 0.018744355,
#  'Loss/regularization_loss': 0.14043629,
#  'Loss/total_loss': 0.22010648,
#  'learning_rate': 0.079815164}
# I0917 20:17:10.543383 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.060925838,
#  'Loss/localization_loss': 0.018744355,
#  'Loss/regularization_loss': 0.14043629,
#  'Loss/total_loss': 0.22010648,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.319s
# I0917 20:17:42.442042 139634860230464 model_lib_v2.py:705] Step 2600 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.0562744,
#  'Loss/localization_loss': 0.014297056,
#  'Loss/regularization_loss': 0.13967784,
#  'Loss/total_loss': 0.21024929,
#  'learning_rate': 0.07978972}
# I0917 20:17:42.442198 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.0562744,
#  'Loss/localization_loss': 0.014297056,
#  'Loss/regularization_loss': 0.13967784,
#  'Loss/total_loss': 0.21024929,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.320s
# I0917 20:18:14.439041 139634860230464 model_lib_v2.py:705] Step 2700 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.046433937,
#  'Loss/localization_loss': 0.021328839,
#  'Loss/regularization_loss': 0.13893849,
#  'Loss/total_loss': 0.20670126,
#  'learning_rate': 0.07976264}
# I0917 20:18:14.439482 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.046433937,
#  'Loss/localization_loss': 0.021328839,
#  'Loss/regularization_loss': 0.13893849,
#  'Loss/total_loss': 0.20670126,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.320s
# I0917 20:18:46.424346 139634860230464 model_lib_v2.py:705] Step 2800 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.04384451,
#  'Loss/localization_loss': 0.025593223,
#  'Loss/regularization_loss': 0.13819152,
#  'Loss/total_loss': 0.20762926,
#  'learning_rate': 0.07973392}
# I0917 20:18:46.424912 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.04384451,
#  'Loss/localization_loss': 0.025593223,
#  'Loss/regularization_loss': 0.13819152,
#  'Loss/total_loss': 0.20762926,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.319s
# I0917 20:19:18.353052 139634860230464 model_lib_v2.py:705] Step 2900 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.050532214,
#  'Loss/localization_loss': 0.017185815,
#  'Loss/regularization_loss': 0.13743484,
#  'Loss/total_loss': 0.20515287,
#  'learning_rate': 0.07970358}
# I0917 20:19:18.353860 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.050532214,
#  'Loss/localization_loss': 0.017185815,
#  'Loss/regularization_loss': 0.13743484,
#  'Loss/total_loss': 0.20515287,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.320s
# I0917 20:19:50.362406 139634860230464 model_lib_v2.py:705] Step 3000 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.03596509,
#  'Loss/localization_loss': 0.010852701,
#  'Loss/regularization_loss': 0.13671981,
#  'Loss/total_loss': 0.1835376,
#  'learning_rate': 0.0796716}
# I0917 20:19:50.362810 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.03596509,
#  'Loss/localization_loss': 0.010852701,
#  'Loss/regularization_loss': 0.13671981,
#  'Loss/total_loss': 0.1835376,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.324s
# I0917 20:20:22.758851 139634860230464 model_lib_v2.py:705] Step 3100 per-step time 0.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.034169007,
#  'Loss/localization_loss': 0.01921195,
#  'Loss/regularization_loss': 0.13601744,
#  'Loss/total_loss': 0.18939841,
#  'learning_rate': 0.07963799}
# I0917 20:20:22.759061 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.034169007,
#  'Loss/localization_loss': 0.01921195,
#  'Loss/regularization_loss': 0.13601744,
#  'Loss/total_loss': 0.18939841,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.320s
# I0917 20:20:54.780347 139634860230464 model_lib_v2.py:705] Step 3200 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.0435689,
#  'Loss/localization_loss': 0.008855428,
#  'Loss/regularization_loss': 0.13529044,
#  'Loss/total_loss': 0.18771477,
#  'learning_rate': 0.07960275}
# I0917 20:20:54.780910 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.0435689,
#  'Loss/localization_loss': 0.008855428,
#  'Loss/regularization_loss': 0.13529044,
#  'Loss/total_loss': 0.18771477,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.318s
# I0917 20:21:26.618463 139634860230464 model_lib_v2.py:705] Step 3300 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.06309725,
#  'Loss/localization_loss': 0.024952551,
#  'Loss/regularization_loss': 0.13463114,
#  'Loss/total_loss': 0.22268096,
#  'learning_rate': 0.07956588}
# I0917 20:21:26.619324 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.06309725,
#  'Loss/localization_loss': 0.024952551,
#  'Loss/regularization_loss': 0.13463114,
#  'Loss/total_loss': 0.22268096,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.321s
# I0917 20:21:58.704518 139634860230464 model_lib_v2.py:705] Step 3400 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.17422025,
#  'Loss/localization_loss': 0.051660392,
#  'Loss/regularization_loss': 0.13424514,
#  'Loss/total_loss': 0.36012578,
#  'learning_rate': 0.079527386}
# I0917 20:21:58.704674 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.17422025,
#  'Loss/localization_loss': 0.051660392,
#  'Loss/regularization_loss': 0.13424514,
#  'Loss/total_loss': 0.36012578,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.319s
# I0917 20:22:30.603192 139634860230464 model_lib_v2.py:705] Step 3500 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.12477512,
#  'Loss/localization_loss': 0.06572327,
#  'Loss/regularization_loss': 0.138587,
#  'Loss/total_loss': 0.32908538,
#  'learning_rate': 0.07948727}
# I0917 20:22:30.604003 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.12477512,
#  'Loss/localization_loss': 0.06572327,
#  'Loss/regularization_loss': 0.138587,
#  'Loss/total_loss': 0.32908538,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.318s
# I0917 20:23:02.434271 139634860230464 model_lib_v2.py:705] Step 3600 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.05916445,
#  'Loss/localization_loss': 0.030613227,
#  'Loss/regularization_loss': 0.13841742,
#  'Loss/total_loss': 0.2281951,
#  'learning_rate': 0.079445526}
# I0917 20:23:02.434833 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.05916445,
#  'Loss/localization_loss': 0.030613227,
#  'Loss/regularization_loss': 0.13841742,
#  'Loss/total_loss': 0.2281951,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.319s
# I0917 20:23:34.339963 139634860230464 model_lib_v2.py:705] Step 3700 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.06897015,
#  'Loss/localization_loss': 0.017481737,
#  'Loss/regularization_loss': 0.13781478,
#  'Loss/total_loss': 0.22426666,
#  'learning_rate': 0.07940216}
# I0917 20:23:34.340172 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.06897015,
#  'Loss/localization_loss': 0.017481737,
#  'Loss/regularization_loss': 0.13781478,
#  'Loss/total_loss': 0.22426666,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.319s
# I0917 20:24:06.269153 139634860230464 model_lib_v2.py:705] Step 3800 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.06200514,
#  'Loss/localization_loss': 0.019150894,
#  'Loss/regularization_loss': 0.13718146,
#  'Loss/total_loss': 0.21833749,
#  'learning_rate': 0.079357184}
# I0917 20:24:06.269651 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.06200514,
#  'Loss/localization_loss': 0.019150894,
#  'Loss/regularization_loss': 0.13718146,
#  'Loss/total_loss': 0.21833749,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.320s
# I0917 20:24:38.251265 139634860230464 model_lib_v2.py:705] Step 3900 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.057301052,
#  'Loss/localization_loss': 0.013829649,
#  'Loss/regularization_loss': 0.13643955,
#  'Loss/total_loss': 0.20757025,
#  'learning_rate': 0.07931058}
# I0917 20:24:38.251838 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.057301052,
#  'Loss/localization_loss': 0.013829649,
#  'Loss/regularization_loss': 0.13643955,
#  'Loss/total_loss': 0.20757025,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.321s
# I0917 20:25:10.349060 139634860230464 model_lib_v2.py:705] Step 4000 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.07514839,
#  'Loss/localization_loss': 0.01965993,
#  'Loss/regularization_loss': 0.1357021,
#  'Loss/total_loss': 0.23051041,
#  'learning_rate': 0.07926236}
# I0917 20:25:10.349302 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.07514839,
#  'Loss/localization_loss': 0.01965993,
#  'Loss/regularization_loss': 0.1357021,
#  'Loss/total_loss': 0.23051041,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.322s
# I0917 20:25:42.521018 139634860230464 model_lib_v2.py:705] Step 4100 per-step time 0.322s
# INFO:tensorflow:{'Loss/classification_loss': 0.04509422,
#  'Loss/localization_loss': 0.015085304,
#  'Loss/regularization_loss': 0.13497391,
#  'Loss/total_loss': 0.19515345,
#  'learning_rate': 0.07921253}
# I0917 20:25:42.521632 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.04509422,
#  'Loss/localization_loss': 0.015085304,
#  'Loss/regularization_loss': 0.13497391,
#  'Loss/total_loss': 0.19515345,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.317s
# I0917 20:26:14.252076 139634860230464 model_lib_v2.py:705] Step 4200 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.052383814,
#  'Loss/localization_loss': 0.011800778,
#  'Loss/regularization_loss': 0.13422456,
#  'Loss/total_loss': 0.19840916,
#  'learning_rate': 0.07916109}
# I0917 20:26:14.252646 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.052383814,
#  'Loss/localization_loss': 0.011800778,
#  'Loss/regularization_loss': 0.13422456,
#  'Loss/total_loss': 0.19840916,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.319s
# I0917 20:26:46.153355 139634860230464 model_lib_v2.py:705] Step 4300 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.025801355,
#  'Loss/localization_loss': 0.019331833,
#  'Loss/regularization_loss': 0.13347736,
#  'Loss/total_loss': 0.17861055,
#  'learning_rate': 0.07910804}
# I0917 20:26:46.153776 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.025801355,
#  'Loss/localization_loss': 0.019331833,
#  'Loss/regularization_loss': 0.13347736,
#  'Loss/total_loss': 0.17861055,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.319s
# I0917 20:27:18.055582 139634860230464 model_lib_v2.py:705] Step 4400 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.03201453,
#  'Loss/localization_loss': 0.012959308,
#  'Loss/regularization_loss': 0.13274051,
#  'Loss/total_loss': 0.17771435,
#  'learning_rate': 0.07905338}
# I0917 20:27:18.055745 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.03201453,
#  'Loss/localization_loss': 0.012959308,
#  'Loss/regularization_loss': 0.13274051,
#  'Loss/total_loss': 0.17771435,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.319s
# I0917 20:27:49.964886 139634860230464 model_lib_v2.py:705] Step 4500 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.039734848,
#  'Loss/localization_loss': 0.0155014135,
#  'Loss/regularization_loss': 0.13203686,
#  'Loss/total_loss': 0.18727313,
#  'learning_rate': 0.07899711}
# I0917 20:27:49.965047 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.039734848,
#  'Loss/localization_loss': 0.0155014135,
#  'Loss/regularization_loss': 0.13203686,
#  'Loss/total_loss': 0.18727313,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.320s
# I0917 20:28:21.995175 139634860230464 model_lib_v2.py:705] Step 4600 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.063591845,
#  'Loss/localization_loss': 0.016417345,
#  'Loss/regularization_loss': 0.13131286,
#  'Loss/total_loss': 0.21132205,
#  'learning_rate': 0.078939244}
# I0917 20:28:21.995751 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.063591845,
#  'Loss/localization_loss': 0.016417345,
#  'Loss/regularization_loss': 0.13131286,
#  'Loss/total_loss': 0.21132205,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.319s
# I0917 20:28:53.876719 139634860230464 model_lib_v2.py:705] Step 4700 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.044321947,
#  'Loss/localization_loss': 0.013381832,
#  'Loss/regularization_loss': 0.13057585,
#  'Loss/total_loss': 0.18827963,
#  'learning_rate': 0.07887978}
# I0917 20:28:53.877319 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.044321947,
#  'Loss/localization_loss': 0.013381832,
#  'Loss/regularization_loss': 0.13057585,
#  'Loss/total_loss': 0.18827963,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.320s
# I0917 20:29:25.862635 139634860230464 model_lib_v2.py:705] Step 4800 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.043358903,
#  'Loss/localization_loss': 0.044943415,
#  'Loss/regularization_loss': 0.12985052,
#  'Loss/total_loss': 0.21815284,
#  'learning_rate': 0.07881871}
# I0917 20:29:25.862832 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.043358903,
#  'Loss/localization_loss': 0.044943415,
#  'Loss/regularization_loss': 0.12985052,
#  'Loss/total_loss': 0.21815284,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.319s
# I0917 20:29:57.774090 139634860230464 model_lib_v2.py:705] Step 4900 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.05558453,
#  'Loss/localization_loss': 0.009801276,
#  'Loss/regularization_loss': 0.12914658,
#  'Loss/total_loss': 0.19453238,
#  'learning_rate': 0.07875605}
# I0917 20:29:57.774691 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.05558453,
#  'Loss/localization_loss': 0.009801276,
#  'Loss/regularization_loss': 0.12914658,
#  'Loss/total_loss': 0.19453238,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.321s
# I0917 20:30:29.837859 139634860230464 model_lib_v2.py:705] Step 5000 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.04695877,
#  'Loss/localization_loss': 0.011349583,
#  'Loss/regularization_loss': 0.12844805,
#  'Loss/total_loss': 0.1867564,
#  'learning_rate': 0.078691795}
# I0917 20:30:29.838430 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.04695877,
#  'Loss/localization_loss': 0.011349583,
#  'Loss/regularization_loss': 0.12844805,
#  'Loss/total_loss': 0.1867564,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.322s
# I0917 20:31:02.084985 139634860230464 model_lib_v2.py:705] Step 5100 per-step time 0.322s
# INFO:tensorflow:{'Loss/classification_loss': 0.05517382,
#  'Loss/localization_loss': 0.00985011,
#  'Loss/regularization_loss': 0.127768,
#  'Loss/total_loss': 0.19279192,
#  'learning_rate': 0.07862595}
# I0917 20:31:02.085446 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.05517382,
#  'Loss/localization_loss': 0.00985011,
#  'Loss/regularization_loss': 0.127768,
#  'Loss/total_loss': 0.19279192,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.320s
# I0917 20:31:34.045977 139634860230464 model_lib_v2.py:705] Step 5200 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.043679766,
#  'Loss/localization_loss': 0.0108621,
#  'Loss/regularization_loss': 0.127066,
#  'Loss/total_loss': 0.18160787,
#  'learning_rate': 0.07855851}
# I0917 20:31:34.046141 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.043679766,
#  'Loss/localization_loss': 0.0108621,
#  'Loss/regularization_loss': 0.127066,
#  'Loss/total_loss': 0.18160787,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.318s
# I0917 20:32:05.862031 139634860230464 model_lib_v2.py:705] Step 5300 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.0564817,
#  'Loss/localization_loss': 0.021959916,
#  'Loss/regularization_loss': 0.12637319,
#  'Loss/total_loss': 0.2048148,
#  'learning_rate': 0.07848949}
# I0917 20:32:05.862593 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.0564817,
#  'Loss/localization_loss': 0.021959916,
#  'Loss/regularization_loss': 0.12637319,
#  'Loss/total_loss': 0.2048148,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.319s
# I0917 20:32:37.745199 139634860230464 model_lib_v2.py:705] Step 5400 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.043749467,
#  'Loss/localization_loss': 0.0062043592,
#  'Loss/regularization_loss': 0.12577252,
#  'Loss/total_loss': 0.17572635,
#  'learning_rate': 0.078418896}
# I0917 20:32:37.745399 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.043749467,
#  'Loss/localization_loss': 0.0062043592,
#  'Loss/regularization_loss': 0.12577252,
#  'Loss/total_loss': 0.17572635,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.319s
# I0917 20:33:09.660659 139634860230464 model_lib_v2.py:705] Step 5500 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.040755983,
#  'Loss/localization_loss': 0.014764359,
#  'Loss/regularization_loss': 0.12508671,
#  'Loss/total_loss': 0.18060705,
#  'learning_rate': 0.078346714}
# I0917 20:33:09.661113 139634860230464 model_lib_v2.py:708] {'Loss/classification_loss': 0.040755983,
#  'Loss/localization_loss': 0.014764359,
#  'Loss/regularization_loss': 0.12508671,
#  'Loss/total_loss': 0.18060705,
#  'learning_rate': 0.078346714}
# ^C

# %%
# %load_ext tensorboard
# %tensorboard --logdir "ssd_mobilenet"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-b069aed2ff14c6cf" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b069aed2ff14c6cf");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
output_dir = 'tuned_model'
# !python3 models/research/object_detection/exporter_main_v2.py \
--input_type image_tensor \
--pipeline_config_path {target_config} \
--trained_checkpoint_dir {path_training} \
--output_directory {output_dir}
# Out:
# 2022-09-17 20:42:57.361042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.367687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.368091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.372612: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-17 20:42:57.373831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.374308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.374746: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.820584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.820921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.821201: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-17 20:42:57.821454: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3117 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# WARNING:tensorflow:From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0917 20:42:58.021699 140210766460736 deprecation.py:614] From /home/nicolas/Documents/Projects/platzi/computer_vision_platzi/venv/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f84c055f610>, because it is not built.
# W0917 20:43:08.489967 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f84c055f610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f84c045c4c0>, because it is not built.
# W0917 20:43:08.584850 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f84c045c4c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d774a60>, because it is not built.
# W0917 20:43:08.584984 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d774a60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d774610>, because it is not built.
# W0917 20:43:08.585095 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d774610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f845d774dc0>, because it is not built.
# W0917 20:43:08.585160 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f845d774dc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d774e80>, because it is not built.
# W0917 20:43:08.585208 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d774e80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d774fa0>, because it is not built.
# W0917 20:43:08.585299 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d774fa0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f845d71f340>, because it is not built.
# W0917 20:43:08.585353 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f845d71f340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d71f490>, because it is not built.
# W0917 20:43:08.585401 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d71f490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d71f550>, because it is not built.
# W0917 20:43:08.585448 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d71f550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f845d71f6a0>, because it is not built.
# W0917 20:43:08.585494 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f845d71f6a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d71f7c0>, because it is not built.
# W0917 20:43:08.585544 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d71f7c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d71f7f0>, because it is not built.
# W0917 20:43:08.585591 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d71f7f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c045ca90>, because it is not built.
# W0917 20:43:08.585636 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c045ca90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d6ef7c0>, because it is not built.
# W0917 20:43:08.585681 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d6ef7c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d70dc40>, because it is not built.
# W0917 20:43:08.585726 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d70dc40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d70dd00>, because it is not built.
# W0917 20:43:08.585771 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d70dd00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d70dfd0>, because it is not built.
# W0917 20:43:08.585815 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d70dfd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d70d400>, because it is not built.
# W0917 20:43:08.585860 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d70d400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d7fea90>, because it is not built.
# W0917 20:43:08.585905 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d7fea90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d7feb20>, because it is not built.
# W0917 20:43:08.585953 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d7feb20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c045cac0>, because it is not built.
# W0917 20:43:08.585999 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c045cac0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d76fb50>, because it is not built.
# W0917 20:43:08.586043 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d76fb50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d72beb0>, because it is not built.
# W0917 20:43:08.586087 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d72beb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d72be20>, because it is not built.
# W0917 20:43:08.586132 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d72be20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d7103a0>, because it is not built.
# W0917 20:43:08.586176 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d7103a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d710400>, because it is not built.
# W0917 20:43:08.586220 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d710400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d710880>, because it is not built.
# W0917 20:43:08.586265 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d710880>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d710820>, because it is not built.
# W0917 20:43:08.586310 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d710820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c045caf0>, because it is not built.
# W0917 20:43:08.586354 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c045caf0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d6669d0>, because it is not built.
# W0917 20:43:08.586399 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d6669d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d66ab50>, because it is not built.
# W0917 20:43:08.586444 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d66ab50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d66adf0>, because it is not built.
# W0917 20:43:08.586493 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d66adf0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d66ae80>, because it is not built.
# W0917 20:43:08.586539 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d66ae80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d66af10>, because it is not built.
# W0917 20:43:08.586584 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d66af10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d66c670>, because it is not built.
# W0917 20:43:08.586628 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d66c670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d66c6a0>, because it is not built.
# W0917 20:43:08.586675 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d66c6a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d664730>, because it is not built.
# W0917 20:43:08.586720 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d664730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d664bb0>, because it is not built.
# W0917 20:43:08.586765 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d664bb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d672670>, because it is not built.
# W0917 20:43:08.586809 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d672670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d672910>, because it is not built.
# W0917 20:43:08.586855 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d672910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d672c40>, because it is not built.
# W0917 20:43:08.586900 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f845d672c40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d672bb0>, because it is not built.
# W0917 20:43:08.586944 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f845d672bb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c00ef130>, because it is not built.
# W0917 20:43:08.586989 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f84c00ef130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f84c00efee0>, because it is not built.
# W0917 20:43:08.587033 140210766460736 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f84c00efee0>, because it is not built.
# 2022-09-17 20:43:16.139530: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W0917 20:43:28.478020 140210766460736 save.py:263] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: tuned_model/saved_model/assets
# I0917 20:43:32.414652 140210766460736 builder_impl.py:783] Assets written to: tuned_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to tuned_model/pipeline.config
# I0917 20:43:32.976498 140210766460736 config_util.py:253] Writing pipeline config file to tuned_model/pipeline.config

# %%
# !zip -r fined_tuned_model.zip tuned_model
# Out:
#   adding: tuned_model/ (stored 0%)
#   adding: tuned_model/checkpoint/ (stored 0%)
#   adding: tuned_model/checkpoint/ckpt-0.data-00000-of-00001 (deflated 8%)
#   adding: tuned_model/checkpoint/ckpt-0.index (deflated 80%)
#   adding: tuned_model/checkpoint/checkpoint (deflated 41%)
#   adding: tuned_model/pipeline.config (deflated 68%)
#   adding: tuned_model/saved_model/ (stored 0%)
#   adding: tuned_model/saved_model/saved_model.pb (deflated 92%)
#   adding: tuned_model/saved_model/variables/ (stored 0%)
#   adding: tuned_model/saved_model/variables/variables.index (deflated 78%)
#   adding: tuned_model/saved_model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: tuned_model/saved_model/assets/ (stored 0%)

# %%
# upload to tensorboard web page

# %%
# cli command
# !tensorboard dev upload --logdir "ssd_mobilenet" --name 'cars motorbike object detection' --description 'training using ssd + mobilenet' --one_shot

# %%
# Published here!!
#https://tensorboard.dev/experiment/wQY50j2JRdSJDdB4vIQOsw/
